# %%
import os
import pandas as pd

# %%
path = os.getcwd()
teste = pd.read_csv(path + "/dfs_by_report/ativo/legado/199412_Ativo.csv", skiprows = 4, encoding="utf-8", sep = ";")

# %%
teste.head()
# Out:
#    3    BANESPA                                                 I  2    \
# 0  4     BRADESCO                                      ...      I  3.0
# 1  5     ITAU                                          ...      I  3.0
# 2  6     BAMERINDUS                                    ...      I  3.0
# 3  7     UNIBANCO                                      ...      I  5.0
# 4  8     SAFRA                                         ...      I  3.0
#
#    2          12/1994  25.935.301  741.275  1.656.050  9.214.586    488.992  \
# 0  2          12/1994  18.341.244  575.989    720.790  1.529.760  3.285.616
# 1  2          12/1994  13.763.029  997.284  1.009.863    735.044  2.371.553
# 2  2          12/1994  11.849.654  210.231  1.167.932  1.131.055  1.710.622
# 3  2          12/1994  10.134.063  625.221    903.672  1.423.836    782.527
# 4  2          12/1994   6.018.190   49.304  1.295.341  1.436.242    199.789
#
#     7.955 11.909.867  -208.008    690.565  57.379   4.953  1.371.686  \
# ...
